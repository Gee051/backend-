# %% [markdown]
# Write a program that allows customers to:
# 1. Create an account with the account number generated if they do not have an account. All generated account numbers should begin with 0
# 2. Log in to the program if they have an account
# 3. Deposit money
# 4. Withdraw money from the account if they have a sufficient amount.
# 5. Users should be able to transfer money to other users in the account
# 6. Users should be able to check their account balances.
# The program should keep running until the user decides to make it log out and/or quit.
# The account data should be stored in a dictionary that looks like that below and kept in a file for persistent storage
#
#
#
# data = {
#     '0123445677' : {
#         "first_name":"John",
#         "last_name" : "Doe ",
#         "login_pin" : "8424"
#         "transaction_pin": "0934",
#         "balance" : 0
#     }
# }

# %%
import random

data = {}

def access():
    user = input("do you have an account number, y/n \n")

    if user == "y":
        login()
            
                
    elif user == "n":
        register()
                
    else:
        print("Enter a valid input, y/n") 

        
        
def login():
    print("$$$$$-- Login --$$$$$")
    
    acc_num = int(input("Enter account number \n"))
    pin = int(input("Enter pin \n"))
    
    for acc, user_info in data.items():
        if acc == acc_num:
            if user_info == pin:
                bankoperation(user_info)
                
        print("Invalid account or password")

    
    
def register():
    
    print("$$$$$ Register $$$$$")
    
    first_name =input("what is your first name? \n")
    last_name = input("what is your last name? \n")   
    login_pin = input("please input a secret  login pin \n")    
    transaction_pin = input("please input a secret transaction pin \n")   
 
    
    newacc_num = generate_acc_num()
    
    data[newacc_num] = [first_name, last_name, login_pin, transaction_pin,]
    
    print("You account has been created")
    print("=== ======= ====")
    print(f"your account number is: {newacc_num}")
    print("keep it safe")
    print("=== ======= ====")
    
    login()
    
def bankoperation(user):
    print("welcome", user[0], user[1])
    
    options = int(input("what would you like to do? \n (1) deposit \n (2) withdraw \n (3) check balance \n (4) transfer \n (5) logout"))
    
    if options == "1":
        deposit()
        
    elif options == "2":
        withdrawal()
        
    elif options == "3":
        checkbalance()
        
    elif options == "2":
        transfer()
        
    elif options == "4":
        logout()
        
    else:
        print("input valid option")
        
        
def deposit():
    amt = int(input("enter amount you want to deposit \n"))
    pin = int(input("Enter pin \n"))
    
    for user_info in data.items():
        if user_info == pin:
            print("=== ===== ====")
            print(f"{amt}, deposited") 
        dep_options = (input("would you like to perform another transaction y/n \n")).lower()
        if dep_options == "y":
            bankoperation(user)
        elif dep_options == "n":
            logout()
        else:
            print("Enter a valid input")
            dep_options
            
            
def user():
    for first_name, last_name in register():
        return(first_name, last_name,) 
    

    
def withdrawal(): 
    amt = int(input("enter amount you want to deposit \n"))
    pin = int(input("Enter password \n"))
    
    for user_info in data.items():
        if user_info == pin:
            print("=== ===== ====")
            print(f"{amt}, withrawn") 
        with_options = (input("would you like to perform another transaction y/n \n")).lower()
        if with_options == "y":
            bankoperation(user)
        elif with_options == "n":
            logout()
        else:
            print("Enter a valid input")
            with_options
    
    
    
def checkbalance(): 
    pin = int(input("Enter password \n"))
    
    for user_info in data.items():
        if user_info == pin:
            print("=== ===== ====")
            # print(f"your balance is: {balance}" ) 
        cb_options = (input("would you like to perform another transaction y/n \n")).lower()
        if cb_options == "y":
            bankoperation(user)
        elif cb_options == "n":
               logout()
        else:
            print("Enter a valid input")
            cb_options
            
            
def transfer():
    bank_name = ["wema" ,"gtb" ,"first" ,"stanbic" ,"eco" ,"kuda", "zenith" ,"opay", "fcmb" , "diamond" ,"palmpay", "internationalbanks"]
    
    amt = int(input("enter amount you want to deposit \n"))
    bank = input("Enter name of bank")
    trans_acc = int(input("Enter account number"))
    pin = int(input("Enter password \n"))
    
    
    for user_info in data.items():
        for bank in bank_name:
            if user_info == pin:
                if bank == bank_name:
                    print("=== ===== ====")
                    print(f"$$$$Transfer successful $$$$$  /n{amt}, transfered") 
        trans_options = (input("would you like to perform another transaction y/n \n")).lower()
        if trans_options == "y":
            bankoperation(user)
        elif trans_options == "n":
            logout()
        else:
            print("Enter a valid input")
            trans_options

def new_func():
    print(f"thank you, {user[0]} \n Bye")
            
            
def logout():
    return(f"thank you, {user[0]} \n Bye")
            
            
            
            
            
def generate_acc_num():
    return random.randrange(11111111111,999999999)



access()

# %%
import json



def init():
    
    
    
    print ("---------- Welcome to Geebanks --------")
    
    
    Accquestion= int(input("do you have an account with us: 1 (yes) 2 (no) \n"))

    if Accquestion == 1:
            
        login()
    elif Accquestion == 2:
            
        register()
    else:
        print("You have selected invalid output")
        init()
        
        
def login():
    print("$$$$$-- Login --$$$$$")
    
    accountnumberfromuser = int(input("Enter account number \n"))
    pin = int(input("Enter pin \n"))
    with open('bankfiles.txt') as file_obj:
        data = json.load(file_obj)
        found_flag = False
    for user_data in data:
        for user_data_key in user_data.keys():
            for user_details in user_data[user_data_key]:
                if accountnumberfromuser in user_details.values():
                    if pin in user_details.values():
                        found_flag = True
                        print("$$$$$-- Login Successful --$$$$$")
                        print(user_details)
    if found_flag == False:
        print('\nAccount not found!')
        login()
                    


def register():
    
    print("$$$$$ Register $$$$$")
    
    first_name =input("what is your first name? \n")
    last_name = input("what is your last name? \n")   
    login_pin = input("please input a secret  login pin \n")    
    transaction_pin = input("please input a secret transaction pin \n")   


    
    accountnumber = generationaccountnumber()
    
    file_data = []
    bank_data = {accountnumber: [{
    "first name": first_name,
    "last name": last_name,   
    "login pin": login_pin,   
    "transaction pin" :transaction_pin   
    
    }]}
    
    print("You account has been created")
    print("=== ======= ====")
    print(f"your account number is: %d" % accountnumber)
    print("safely keep it")
    print("=== ======= ====")
    
    
    import os
    if os.stat('bankfiles.txt').st_size == 0:
        file_data.append(bank_data)
        with open('bankfiles.txt') as files:
            json.dump(file_data, files)
            
    else:
        with open('bankfiles.txt') as files:
            data = json.load(files)
            data.append(bank_data)
            with open('bankfiles.txt') as files:
                json.dump(data, files)
    
    
    login()
    
    # file_data = []
    # bank_data = {accountnumber: [{
    # "first name": first_name,
    # "last name": last_name,   
    # "login pin": login_pin,   
    # "transaction pin" :transaction_pin   
    
    # }]}
    

    
import random    
def generationaccountnumber():
        
    return random.randrange(1111111111,9999999999)
    
generationaccountnumber()
